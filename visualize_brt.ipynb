# %%
import odp
from odp.Plots import plot_isosurface, PlotOptions
import numpy as np
from atu.brt.brt_6D import g

# %%
V = np.load('./atu/envs/assets/brts/6d.npy')

# %%
V.shape
# Out:
# (20, 20, 10, 20, 20, 10)

# %%
p = PlotOptions(do_plot=True, plot_type="3d_plot", plotDims=[0, 1, 2], slicesCut=[5, 5, 5])
from odp.Shapes import *
ivf = CylinderShape(g, np.array([2, 3, 4, 5]), np.zeros(6), radius=1)
plot_isosurface(g, ivf, p)
# Out:
# Plotting beautiful plots. Please wait
# Please check the plot on your browser.
